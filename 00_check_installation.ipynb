# %%
import sys
sys.version
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'

# %%
import tensorflow as tf
tf.__version__ #Should work and give 1.14.0
# Out:
# '1.14.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(range(100), np.sin(0.1 * np.array(range(100))))
plt.show()
plt.plot(range(100), np.sin(0.1 * np.array(range(100))))
plt.show()
